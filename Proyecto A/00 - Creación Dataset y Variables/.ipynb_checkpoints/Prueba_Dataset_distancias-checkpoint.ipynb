# %% [markdown]
# # Paquetes

# %%
import pandas as pd
import numpy as np
from urllib.parse import urlparse
import tldextract

# %% [markdown]
# # Datasets

# %% [markdown]
# ## Datasets Valids

# %% [markdown]
# Usando los datasets obtenidos y generamos podemos unirlos para generar un dataset completo para la detección de phishing.

# %%
data_phish_valid1 = pd.read_csv('Datasets/verified_online.csv')
data_phish_valid1['phishing'] = np.ones(data_phish_valid1.shape[0])
data_phish_valid1 = data_phish_valid1[['url','phishing']]
data_phish_valid1
# Out:
#                                                      url  phishing
# 0          http://populaire-pro-dsp.com/PopIbet/app.html       1.0
# 1      https://talkingtree.staging-technologies.com/v...       1.0
# 2                         https://yahoopdf.yolasite.com/       1.0
# 3      https://www4.sndc-crad-nem-inedx.scottfaraday1.cn       1.0
# 4                https://annzon-ihbsf-co-jp.mbhcxy.buzz/       1.0
# ...                                                  ...       ...
# 11102                          http://gkjx168.com/images       1.0
# 11103       http://www.habbocreditosparati.blogspot.com/       1.0
# 11104  http://creditiperhabbogratissicuro100.blogspot...       1.0
# 11105  http://mundovirtualhabbo.blogspot.com/2009_01_...       1.0
# 11106  http://aijcs.blogspot.com/2005/03/colourful-li...       1.0
#
# [11107 rows x 2 columns]

# %%
data_phish_valid.iloc[60:80]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5496/2087796216.py in <module>
# ----> 1 data_phish_valid.iloc[60:80]
#
# NameError: name 'data_phish_valid' is not defined

# %%
data_phish_valid2 = pd.read_csv('Datasets/Dataset_Phishing_Valid.csv')
data_phish_valid2['phishing'] = np.ones(data_phish_valid2.shape[0])
data_phish_valid2 = data_phish_valid2[['URL','phishing']]
data_phish_valid2.columns = ['url', 'phishing']
data_phish_valid2
# Out:
#                                                      url  phishing
# 0                             https://fb.help-sync10.ga/       1.0
# 1      https://xefcxersewadxfrdea12wa.000webhostapp.c...       1.0
# 2      http://protectyouraccount.fromamazoncardupdate...       1.0
# 3                               http://srnbc.nrcktoa.cn/       1.0
# 4                               http://srnbc.zunflbo.cn/       1.0
# ...                                                  ...       ...
# 19995                https://rakuten.email-cecile5.net/l       1.0
# 19996                https://rakuten.email-cecile3.net/l       1.0
# 19997                      https://aionmrn.serveirc.com/       1.0
# 19998                    https://aiolinorm.serveirc.com/       1.0
# 19999               https://rakuten.email-cecile4.shop/l       1.0
#
# [20000 rows x 2 columns]

# %% [markdown]
# ## Dataset Top Webs

# %%
data_top_urls = pd.read_csv('Datasets/Dataset_Top_urls.csv')
data_top_urls = data_top_urls.iloc[:5000]
data_top_urls['phishing'] = np.zeros(data_top_urls.shape[0])
data_top_urls = data_top_urls[['URL','phishing']]
data_top_urls.columns = ['url', 'phishing']
data_top_urls
# Out:
#                       url  phishing
# 0              google.com       0.0
# 1             youtube.com       0.0
# 2            facebook.com       0.0
# 3               baidu.com       0.0
# 4           wikipedia.org       0.0
# ...                   ...       ...
# 4995            uspto.gov       0.0
# 4996           elastic.co       0.0
# 4997            vkmag.com       0.0
# 4998            mtime.com       0.0
# 4999  mercadolibre.com.pe       0.0
#
# [5000 rows x 2 columns]

# %% [markdown]
# Podríamos comparar dominios correctos usando estos top urls contra los dominios de los urls analizados.

# %%
data_top_urls['domain'] = data_top_urls['url'].apply(lambda x: tldextract.extract(x).domain)
#data_top_urls['subdomain'] = data_top_urls['url'].apply(lambda x: tldextract.extract(x).subdomain)
data_top_urls.iloc[70:90]
# Out:
#                       url  phishing             domain
# 70             paypal.com       0.0             paypal
# 71    microsoftonline.com       0.0    microsoftonline
# 72          google.com.tw       0.0             google
# 73          google.com.au       0.0             google
# 74           whatsapp.com       0.0           whatsapp
# 75              google.pl       0.0             google
# 76           xhamster.com       0.0           xhamster
# 77       detail.tmall.com       0.0              tmall
# 78              diply.com       0.0              diply
# 79           google.co.id       0.0             google
# 80              adobe.com       0.0              adobe
# 81             coccoc.com       0.0             coccoc
# 82         craigslist.org       0.0         craigslist
# 83           nicovideo.jp       0.0          nicovideo
# 84               txxx.com       0.0               txxx
# 85            dropbox.com       0.0            dropbox
# 86              amazon.de       0.0             amazon
# 87          google.com.ar       0.0             google
# 88              amazon.in       0.0             amazon
# 89  googleusercontent.com       0.0  googleusercontent

# %% [markdown]
# ## Dataset Invalid

# %%
data_phish_invalid = pd.read_csv('Datasets/Dataset_Phishing_Invalid.csv')
data_phish_invalid['phishing'] = np.zeros(data_phish_invalid.shape[0])
data_phish_invalid = data_phish_invalid[['URL','phishing']]
data_phish_invalid.columns = ['url', 'phishing']
data_phish_invalid
# Out:
#                                                      url  phishing
# 0                     https://www.paysafecard.com/fr-ch/       0.0
# 1                                    https://cncs.gob.do       0.0
# 2                      https://eticket.migracion.gob.do/       0.0
# 3              https://www.indeed.com/legal?hl=en_US#tos       0.0
# 4                         https://www.peoplemetrics.com/       0.0
# ...                                                  ...       ...
# 28215  http://searchengineland.com/mapquest-reboot-ne...       0.0
# 28216  http://feeds.searchengineland.com/~r/searcheng...       0.0
# 28217  http://www.seroundtable.com/photos/google-ligh...       0.0
# 28218  http://feeds.seroundtable.com/~r/SearchEngineR...       0.0
# 28219  http://feeds.searchengineland.com/~r/searcheng...       0.0
#
# [28220 rows x 2 columns]

# %% [markdown]
# ## Generación del Dataset

# %% [markdown]
# Generamos el dataset completo y mezclamos las observaciones.

# %%
# Pruebo sin incluir top_urls
data = pd.concat([data_phish_invalid, data_phish_valid1, data_phish_valid2])
data = data.sample(frac=1, random_state = 42).reset_index(drop=True)
#data.to_csv('Dataset.csv')
data.head(10)
# Out:
#                                                  url  phishing
# 0               http://3.82.83.31/inter/projet/open/       1.0
# 1  https://www.musicreadingsavant.com/musicgiftsg...       1.0
# 2  http://click.email.thinkgeek.com/profile_cente...       0.0
# 3           https://99conferences.com/privacy_policy       0.0
# 4       https://www.amazon-jp.paypewqa.club/404.html       1.0
# 5         https://yamaxunlgkjeyuwflkdshg.xyz/mobile/       1.0
# 6         http://tempuri.org/:MATERBLOB_SearchResult       0.0
# 7                      https://6e33r.codesandbox.io/       1.0
# 8    https://www.whatsappchatnow2021fgg.duckdns.org/       1.0
# 9                         https://docamo.ne.ieqh.xyz       1.0

# %%
data['phishing'].value_counts()
# Out:
# 1.0    31107
# 0.0    28220
# Name: phishing, dtype: int64

# %% [markdown]
# # Descomposición del URL

# %% [markdown]
# ## Variable Scheme
#
# Los 5000 urls obtenidos de alexa no tienen esta porción. Estos links podrían introducir sesgos en el análisis. Podemos analizar estos links que tienen 'spam' como scheme, pero en principio son observaciones que no se incluirían.

# %%
data['scheme'] = data['url'].apply(lambda x: urlparse(x).scheme)

# %%
# Eliminamos observaciones con scheme diferente a http y https.
data = data.query('scheme in ["http", "https"]')

# %%
data['scheme'].value_counts()
# Out:
# http     30994
# https    28319
# Name: scheme, dtype: int64

# %%
pd.crosstab(index = data['phishing'], columns = data['scheme'])
# Out:
# scheme     http  https
# phishing
# 0.0       19615   8591
# 1.0       11379  19728

# %% [markdown]
# ## Variable Domain

# %% [markdown]
# Extraemos el dominio completo de los urls analizados.

# %%
data['domain_complete'] = data['url'].apply(lambda x: urlparse(x).netloc)

# %% [markdown]
# Hay dos urls que no parecerían tener dominio.

# %%
print((data['domain_complete'] == '').sum())
data = data.query('domain_complete != ""')
# Out:
# 2

# %%
data.head()
# Out:
#                                                  url  phishing scheme  \
# 0               http://3.82.83.31/inter/projet/open/       1.0   http
# 1  https://www.musicreadingsavant.com/musicgiftsg...       1.0  https
# 2  http://click.email.thinkgeek.com/profile_cente...       0.0   http
# 3           https://99conferences.com/privacy_policy       0.0  https
# 4       https://www.amazon-jp.paypewqa.club/404.html       1.0  https
#
#                domain_complete
# 0                   3.82.83.31
# 1   www.musicreadingsavant.com
# 2    click.email.thinkgeek.com
# 3            99conferences.com
# 4  www.amazon-jp.paypewqa.club

# %%
data['domain_complete']
# Out:
# 0                         3.82.83.31
# 1         www.musicreadingsavant.com
# 2          click.email.thinkgeek.com
# 3                  99conferences.com
# 4        www.amazon-jp.paypewqa.club
#                     ...
# 59322                      o5ojfa.cn
# 59323               gwisalltrack.com
# 59324           fonts.googleapis.com
# 59325               liveonline24.com
# 59326        olx-mb.ownoffferta.casa
# Name: domain_complete, Length: 59311, dtype: object

# %% [markdown]
# ### Domain, Subdomain y Suffix

# %% [markdown]
# Del dominio completo se puede extraer el sufijo, el dominio y el subdominio.
#
# * Con el sufijo se puede armar una variable categórica.
# * Revisar el dominio y subdominio (se podrían analizar juntos o separados).

# %%
data['domain'] = data['domain_complete'].apply(lambda x: tldextract.extract(x).domain)
data['subdomain'] = data['domain_complete'].apply(lambda x: tldextract.extract(x).subdomain)
data['suffix'] = data['domain_complete'].apply(lambda x: tldextract.extract(x).suffix)

# %%
data
# Out:
#                                                      url  phishing scheme  \
# 0                   http://3.82.83.31/inter/projet/open/       1.0   http
# 1      https://www.musicreadingsavant.com/musicgiftsg...       1.0  https
# 2      http://click.email.thinkgeek.com/profile_cente...       0.0   http
# 3               https://99conferences.com/privacy_policy       0.0  https
# 4           https://www.amazon-jp.paypewqa.club/404.html       1.0  https
# ...                                                  ...       ...    ...
# 59322                                  http://o5ojfa.cn/       1.0   http
# 59323  http://gwisalltrack.com/gwisalltrack_web/makin...       1.0   http
# 59324     https://fonts.googleapis.com/css?family=Bitter       0.0  https
# 59325  http://liveonline24.com/michigan-vs-ohio-state...       0.0   http
# 59326                    https://olx-mb.ownoffferta.casa       1.0  https
#
#                    domain_complete              domain      subdomain suffix
# 0                       3.82.83.31          3.82.83.31
# 1       www.musicreadingsavant.com  musicreadingsavant            www    com
# 2        click.email.thinkgeek.com           thinkgeek    click.email    com
# 3                99conferences.com       99conferences                   com
# 4      www.amazon-jp.paypewqa.club            paypewqa  www.amazon-jp   club
# ...                            ...                 ...            ...    ...
# 59322                    o5ojfa.cn              o5ojfa                    cn
# 59323             gwisalltrack.com        gwisalltrack                   com
# 59324         fonts.googleapis.com          googleapis          fonts    com
# 59325             liveonline24.com        liveonline24                   com
# 59326      olx-mb.ownoffferta.casa         ownoffferta         olx-mb   casa
#
# [59311 rows x 7 columns]

# %% [markdown]
# Podemos eliminar los prefijos "www." de el subdomain y crear una variable de domain + subdomain. Esto se puede realizar porque "entiendo" que todos los urls se pueden escribir con o sin 'www' por lo que incluirlos en el análisis puede afectar innecesariamente.

# %%
data['subdomain'] = data['subdomain'].str.replace('www.', '')
data['subdomain'] = data['subdomain'].str.replace('www', '')
# Out:
# C:\Users\kiri\AppData\Local\Temp/ipykernel_5496/7581208.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['subdomain'] = data['subdomain'].str.replace('www.', '')

# %%
data['subdomain'] = data['subdomain'] + '.'
data['subdomain'] = data['subdomain'].replace('.', '')

# %% [markdown]
# Creamos una variable que tiene tanto el domain como subdomain de la página.

# %%
data['domain_subdomain'] = data['subdomain'] + data['domain']

# %% [markdown]
# ### Suffix

# %% [markdown]
# Para el sufijo se pueden generar variables categóricas incluyendo a todas las clases poco frecuentes en una categoría "Otros".

# %%
data['suffix'].value_counts().head(20)
# Out:
# com       28101
# org        3154
# net        2631
# ru         1793
# xyz        1435
# cn         1006
# com.br      996
# biz         820
#             747
# co.uk       729
# de          624
# co          599
# tk          593
# info        500
# me          494
# fr          488
# ly          468
# top         445
# shop        421
# eu          408
# Name: suffix, dtype: int64

# %% [markdown]
# Cuando el sufijo es 0 el dominio es una IP.

# %%
data[data['suffix'] == '']
# Out:
#                                                      url  phishing scheme  \
# 0                   http://3.82.83.31/inter/projet/open/       1.0   http
# 56                               https://155.94.170.243/       1.0  https
# 130    http://51.13.103.32/reconfirm.php?sf58gfd1s689...       1.0   http
# 187          http://74.53.43.162/%7Enet2794/persian.html       0.0   http
# 345                 http://104.223.119.229/CiudadInforma       1.0   http
# ...                                                  ...       ...    ...
# 59072         http://20.151.216.110/Finance/tang/pin.php       1.0   http
# 59151         http://20.151.172.148/Finance/tang/pin.php       1.0   http
# 59165          http://8.135.99.111/dad/netflix/login708/       1.0   http
# 59268                            https://155.94.140.229/       1.0  https
# 59294                         http://103.211.143.23/ree/       1.0   http
#
#        domain_complete           domain subdomain suffix domain_subdomain
# 0           3.82.83.31       3.82.83.31                        3.82.83.31
# 56      155.94.170.243   155.94.170.243                    155.94.170.243
# 130       51.13.103.32     51.13.103.32                      51.13.103.32
# 187       74.53.43.162     74.53.43.162                      74.53.43.162
# 345    104.223.119.229  104.223.119.229                   104.223.119.229
# ...                ...              ...       ...    ...              ...
# 59072   20.151.216.110   20.151.216.110                    20.151.216.110
# 59151   20.151.172.148   20.151.172.148                    20.151.172.148
# 59165     8.135.99.111     8.135.99.111                      8.135.99.111
# 59268   155.94.140.229   155.94.140.229                    155.94.140.229
# 59294   103.211.143.23   103.211.143.23                    103.211.143.23
#
# [747 rows x 8 columns]

# %% [markdown]
# ## Variable Path

# %%
data['path'] = data['url'].apply(lambda x: urlparse(x).path)

# %%
print((data['path'] == '').sum())
print((data['path'] == '/').sum())
# Out:
# 3303
# 15974

# %%
data['url'].str.count('\\=').value_counts()
# Out:
# 0     46849
# 1      5102
# 2      1684
# 3      1514
# 4      1472
# 5       628
# 6       521
# 7       313
# 12      260
# 8       250
# 10      152
# 9       145
# 11      102
# 13       69
# 14       36
# 15       22
# 16       17
# 17       16
# 20       16
# 18       13
# 21       11
# 23       11
# 24       11
# 26       10
# 30       10
# 29        9
# 22        9
# 25        9
# 28        8
# 33        7
# 19        6
# 31        6
# 32        6
# 27        3
# 53        2
# 35        2
# 38        2
# 42        2
# 39        2
# 66        1
# 68        1
# 34        1
# 49        1
# Name: url, dtype: int64

# %% [markdown]
# ## Creación de Variables

# %%
data_model = data.copy()
data_model.head()
# Out:
#                                                  url  phishing scheme  \
# 0               http://3.82.83.31/inter/projet/open/       1.0   http
# 1  https://www.musicreadingsavant.com/musicgiftsg...       1.0  https
# 2  http://click.email.thinkgeek.com/profile_cente...       0.0   http
# 3           https://99conferences.com/privacy_policy       0.0  https
# 4       https://www.amazon-jp.paypewqa.club/404.html       1.0  https
#
#                domain_complete              domain     subdomain suffix  \
# 0                   3.82.83.31          3.82.83.31
# 1   www.musicreadingsavant.com  musicreadingsavant                  com
# 2    click.email.thinkgeek.com           thinkgeek  click.email.    com
# 3            99conferences.com       99conferences                  com
# 4  www.amazon-jp.paypewqa.club            paypewqa    amazon-jp.   club
#
#         domain_subdomain                                               path
# 0             3.82.83.31                                /inter/projet/open/
# 1     musicreadingsavant  /musicgiftsgalore.com/wp-admin/js/widgets/upgr...
# 2  click.email.thinkgeek                               /profile_center.aspx
# 3          99conferences                                    /privacy_policy
# 4     amazon-jp.paypewqa                                          /404.html

# %%
# Variables del dominio
# Cuenta los puntos
data_model['dom_n_puntos'] = data_model['domain_subdomain'].str.count('\\.')
data_model['dom_n_guion'] = data_model['domain_subdomain'].str.count('\\-')
data_model['dom_n_guionbajo'] = data_model['domain_subdomain'].str.count('\\_')

# Cuenta el largo total del dominio + subdominio
data_model['dom_len_tot'] = data_model['domain_subdomain'].str.len()
# Cuenta el largo del dominio y subdominio por separado
data_model['dom_len'] = data_model['domain'].str.len()
data_model['dom_len_sub'] = data_model['subdomain'].str.len()

# Cuenta vocales
data_model['dom_vocales'] = data_model['domain_subdomain'].str.lower().str.count(r'[aeiou]')
# Cuenta consonantes
data_model['dom_cons'] = data_model['domain_subdomain'].str.lower().str.count(r'[a-z]') - data_model['dom_vocales']
# Cuenta números
data_model['dom_num'] = data_model['domain_subdomain'].str.count('\d')
# Cuenta cantidad de caracteres diferentes
data_model['dom_car_dif'] = data_model['domain_subdomain'].apply(set).apply(len)

# Dominio es IP
data_model['dom_ip'] = pd.get_dummies(data_model['suffix'] == '', drop_first=True)

# %%
# Variable dummy Scheme
sch_dummies = pd.get_dummies(data_model['scheme'], prefix='sch')
data_model = pd.concat([data_model, sch_dummies], axis = 1)

# %%
# Variables de Suffix
data_model['suf_len'] = data_model['suffix'].str.len()

# Creamos e imprimimos una lista con el top 5 de sufijos.
top_suf_list = list(data_model['suffix'].value_counts().head(5).index)
print(f'Lista de URLs top 5: {top_suf_list}')
print(data_model['suffix'].value_counts().head(5))
# Creamos una variable suffix2 para crear las dummies.
data_model['suffix2'] = data_model['suffix']
# Asignamos categoría 'other' a todas las clases que no pertenezcan a top_suf_list.
data_model.loc[data_model['suffix2'].isin(top_suf_list).apply(np.bitwise_not), 'suffix2'] = 'other'
# Armamos las columnas dummy.
suf_dummies = pd.get_dummies(data_model['suffix2'], prefix='suf')
data_model = pd.concat([data_model, suf_dummies], axis = 1)
# Out:
# Lista de URLs top 5: ['com', 'org', 'net', 'ru', 'xyz']
# com    28101
# org     3154
# net     2631
# ru      1793
# xyz     1435
# Name: suffix, dtype: int64

# %% [markdown]
# Esta línea permite probar caracteres para chequear si se encuentran en el dominio.

# %%
data_model['domain_subdomain'].str.count('\\*').value_counts()
# Out:
# 0    59311
# Name: domain_subdomain, dtype: int64

# %% [markdown]
# Fueron probados y tienen nula varianza:
# * /
# * ?
# * =
# * @
# * &
# * !
# * ,
# * :
# * ;
# * { }
# * %
# * #
# * +

# %%
data_model
# Out:
#                                                      url  phishing scheme  \
# 0                   http://3.82.83.31/inter/projet/open/       1.0   http
# 1      https://www.musicreadingsavant.com/musicgiftsg...       1.0  https
# 2      http://click.email.thinkgeek.com/profile_cente...       0.0   http
# 3               https://99conferences.com/privacy_policy       0.0  https
# 4           https://www.amazon-jp.paypewqa.club/404.html       1.0  https
# ...                                                  ...       ...    ...
# 59322                                  http://o5ojfa.cn/       1.0   http
# 59323  http://gwisalltrack.com/gwisalltrack_web/makin...       1.0   http
# 59324     https://fonts.googleapis.com/css?family=Bitter       0.0  https
# 59325  http://liveonline24.com/michigan-vs-ohio-state...       0.0   http
# 59326                    https://olx-mb.ownoffferta.casa       1.0  https
#
#                    domain_complete              domain     subdomain suffix  \
# 0                       3.82.83.31          3.82.83.31
# 1       www.musicreadingsavant.com  musicreadingsavant                  com
# 2        click.email.thinkgeek.com           thinkgeek  click.email.    com
# 3                99conferences.com       99conferences                  com
# 4      www.amazon-jp.paypewqa.club            paypewqa    amazon-jp.   club
# ...                            ...                 ...           ...    ...
# 59322                    o5ojfa.cn              o5ojfa                   cn
# 59323             gwisalltrack.com        gwisalltrack                  com
# 59324         fonts.googleapis.com          googleapis        fonts.    com
# 59325             liveonline24.com        liveonline24                  com
# 59326      olx-mb.ownoffferta.casa         ownoffferta       olx-mb.   casa
#
#             domain_subdomain  \
# 0                 3.82.83.31
# 1         musicreadingsavant
# 2      click.email.thinkgeek
# 3              99conferences
# 4         amazon-jp.paypewqa
# ...                      ...
# 59322                 o5ojfa
# 59323           gwisalltrack
# 59324       fonts.googleapis
# 59325           liveonline24
# 59326     olx-mb.ownoffferta
#
#                                                     path  dom_n_puntos  ...  \
# 0                                    /inter/projet/open/             3  ...
# 1      /musicgiftsgalore.com/wp-admin/js/widgets/upgr...             0  ...
# 2                                   /profile_center.aspx             2  ...
# 3                                        /privacy_policy             0  ...
# 4                                              /404.html             1  ...
# ...                                                  ...           ...  ...
# 59322                                                  /             0  ...
# 59323             /gwisalltrack_web/making_a_payment.htm             0  ...
# 59324                                               /css             1  ...
# 59325                      /michigan-vs-ohio-state-2015/             0  ...
# 59326                                                                1  ...
#
#        sch_http  sch_https  suf_len  suffix2  suf_com  suf_net  suf_org  \
# 0             1          0        0    other        0        0        0
# 1             0          1        3      com        1        0        0
# 2             1          0        3      com        1        0        0
# 3             0          1        3      com        1        0        0
# 4             0          1        4    other        0        0        0
# ...         ...        ...      ...      ...      ...      ...      ...
# 59322         1          0        2    other        0        0        0
# 59323         1          0        3      com        1        0        0
# 59324         0          1        3      com        1        0        0
# 59325         1          0        3      com        1        0        0
# 59326         0          1        4    other        0        0        0
#
#        suf_other  suf_ru  suf_xyz
# 0              1       0        0
# 1              0       0        0
# 2              0       0        0
# 3              0       0        0
# 4              1       0        0
# ...          ...     ...      ...
# 59322          1       0        0
# 59323          0       0        0
# 59324          0       0        0
# 59325          0       0        0
# 59326          1       0        0
#
# [59311 rows x 30 columns]

# %% [markdown]
# # Prueba Distancia de Strings

# %%
import jellyfish

# %% [markdown]
# Link de la documentación de la libreria.
#
# https://jellyfish.readthedocs.io/en/latest/comparison.html
#
# Link de la explicación de Jaro Distance.
#
# https://en.wikipedia.org/wiki/Jaro%E2%80%93Winkler_distance

# %%
links_url = [
                'amazon.com', 
                'amazon.co.safeamazonsecure.icu', 
                'aoinamozm.servebeer.com', 
                'breakevents.de', 
                'spectralwirejewelry.com', 
                'eim.ae.iwc.static.royalgatetransport.ae',
                'www.amazonlogistics.eu',
                'www.amazon.fr'
            ]

for link in links_url:
    print(tldextract.extract(link))
# Out:
# ExtractResult(subdomain='', domain='amazon', suffix='com')
# ExtractResult(subdomain='amazon.co', domain='safeamazonsecure', suffix='icu')
# ExtractResult(subdomain='aoinamozm', domain='servebeer', suffix='com')
# ExtractResult(subdomain='', domain='breakevents', suffix='de')
# ExtractResult(subdomain='', domain='spectralwirejewelry', suffix='com')
# ExtractResult(subdomain='eim.ae.iwc.static', domain='royalgatetransport', suffix='ae')
# ExtractResult(subdomain='www', domain='amazonlogistics', suffix='eu')
# ExtractResult(subdomain='www', domain='amazon', suffix='fr')

# %% [markdown]
# La mejor métrica de similitud entre strings parece ser la distancia Jaro - Winkler. Esta es una mejor prueba que las hechas más abajo. Acá los dominios no tienen el sufijo y no incluyen "www", algo que en las comparaciones de abajo no está tenido en cuenta y altera los resultados.

# %%
print(jellyfish.jaro_winkler('amazon', 'amazon'))
print(jellyfish.jaro_winkler('amazon.co.safeamazonsecure', 'amazon'))
print(jellyfish.jaro_winkler('aoinamozm.servebeer', 'amazon'))
print(jellyfish.jaro_winkler('breakevents', 'amazon'))
print(jellyfish.jaro_winkler('spectralwirejewelry', 'amazon'))
print(jellyfish.jaro_winkler('eim.ae.iwc.static.royalgatetransport', 'amazon'))
print(jellyfish.jaro_winkler('amazonlogistics', 'amazon'))
print(jellyfish.jaro_winkler('amazon', 'amazon'))
# Out:
# 1.0
# 0.8461538461538461
# 0.6608187134502924
# 0.5050505050505051
# 0.4064327485380117
# 0.5092592592592592
# 0.88
# 1.0

# %%
for link in links_url:
    print(f'Link: {link} - metric {jellyfish.jaro_distance(tldextract.extract(link).domain+tldextract.extract(link).subdomain, "amazon")}')
# Out:
# Link: amazon.com - metric 1.0
# Link: amazon.co.safeamazonsecure.icu - metric 0.6911111111111111
# Link: aoinamozm.servebeer.com - metric 0.5555555555555555
# Link: breakevents.de - metric 0.5050505050505051
# Link: spectralwirejewelry.com - metric 0.4064327485380117
# Link: eim.ae.iwc.static.royalgatetransport.ae - metric 0.5103174603174603
# Link: www.amazonlogistics.eu - metric 0.7777777777777777
# Link: www.amazon.fr - metric 0.8888888888888888

# %%
for link in links_url:
    print(f'Link: {link} - metric {jellyfish.jaro_winkler(tldextract.extract(link).domain+tldextract.extract(link).subdomain, "amazon")}','--',tldextract.extract(link).domain+tldextract.extract(link).subdomain)
# Out:
# Link: amazon.com - metric 1.0 -- amazon
# Link: amazon.co.safeamazonsecure.icu - metric 0.6911111111111111 -- safeamazonsecureamazon.co
# Link: aoinamozm.servebeer.com - metric 0.5555555555555555 -- servebeeraoinamozm
# Link: breakevents.de - metric 0.5050505050505051 -- breakevents
# Link: spectralwirejewelry.com - metric 0.4064327485380117 -- spectralwirejewelry
# Link: eim.ae.iwc.static.royalgatetransport.ae - metric 0.5103174603174603 -- royalgatetransporteim.ae.iwc.static
# Link: www.amazonlogistics.eu - metric 0.8666666666666666 -- amazonlogisticswww
# Link: www.amazon.fr - metric 0.9333333333333333 -- amazonwww

# %%
for link in links_url:
    print(f'Link: {link} - metric {jellyfish.hamming_distance(link, "amazon.com")}')
# Out:
# Link: amazon.com - metric 0
# Link: amazon.co.safeamazonsecure.icu - metric 21
# Link: aoinamozm.servebeer.com - metric 22
# Link: breakevents.de - metric 14
# Link: spectralwirejewelry.com - metric 23
# Link: eim.ae.iwc.static.royalgatetransport.ae - metric 38
# Link: www.amazonlogistics.eu - metric 21
# Link: www.amazon.fr - metric 12

# %%
for link in links_url:
    print(f'Link: {link} - metric {jellyfish.levenshtein_distance(link, "amazon.com")}')
# Out:
# Link: amazon.com - metric 0
# Link: amazon.co.safeamazonsecure.icu - metric 20
# Link: aoinamozm.servebeer.com - metric 16
# Link: breakevents.de - metric 12
# Link: spectralwirejewelry.com - metric 18
# Link: eim.ae.iwc.static.royalgatetransport.ae - metric 34
# Link: www.amazonlogistics.eu - metric 15
# Link: www.amazon.fr - metric 7

# %%
for link in links_url:
    print(f'Link: {link} - metric {jellyfish.damerau_levenshtein_distance(link, "amazon.com")}')
# Out:
# Link: amazon.com - metric 0
# Link: amazon.co.safeamazonsecure.icu - metric 20
# Link: aoinamozm.servebeer.com - metric 16
# Link: breakevents.de - metric 12
# Link: spectralwirejewelry.com - metric 18
# Link: eim.ae.iwc.static.royalgatetransport.ae - metric 34
# Link: www.amazonlogistics.eu - metric 15
# Link: www.amazon.fr - metric 7

# %%
row = 40
data.iloc[row:row+20]
# Out:
#                                                   url  phishing scheme  \
# 40                           http://gitlab.axsoft.ru/       0.0   http
# 41  https://dbs.mc.eu1.kontiki.com/global2/content...       1.0  https
# 42    http://anazon.co.ip.jpza.shop/0p2A.php?qu54=jp/       1.0   http
# 43                    http://schema.org/ConfirmAction       0.0   http
# 44  https://kmsk.jp/wp-content/israel/dhlil/rwoaop...       1.0  https
# 45  https://takeonestudio.com.pk/mkjhgj/lkjhg/bGJ1...       1.0  https
# 46                https://bexbadjrujjmf09.weebly.com/       1.0  https
# 47     http://hutoknepper.de/AutoScout24%20-phone.php       1.0   http
# 48  http://binarybenliveload.com/autosz/logsession...       1.0   http
# 49              https://jpanamz-amanrt.servehttp.com/       1.0  https
# 50  https://crazy-clarke.107-175-136-137.plesk.pag...       1.0  https
# 51                     https://yyyahooooo.weebly.com/       1.0  https
# 52            https://plansvsalvttr2.webcindario.com/       1.0  https
# 53  http://hostpoint.ch.121c0291.net2care.com/ar2/...       1.0   http
# 54  https://link.do/redirect.php?to=https://prijav...       1.0  https
# 55  http://classof1.com/homework_answers/zoology/c...       0.0   http
# 56                            https://155.94.170.243/       1.0  https
# 57       https://informationcradle.com/dallas-raines/       0.0  https
# 58                                 https://bazaar.tf/       0.0  https
# 59  http://diamondbank.com/index.php/diamond-mobil...       0.0   http
#
#                             domain_complete             domain  \
# 40                         gitlab.axsoft.ru             axsoft
# 41                   dbs.mc.eu1.kontiki.com            kontiki
# 42                   anazon.co.ip.jpza.shop               jpza
# 43                               schema.org             schema
# 44                                  kmsk.jp               kmsk
# 45                     takeonestudio.com.pk      takeonestudio
# 46               bexbadjrujjmf09.weebly.com             weebly
# 47                           hutoknepper.de        hutoknepper
# 48                    binarybenliveload.com  binarybenliveload
# 49             jpanamz-amanrt.servehttp.com          servehttp
# 50  crazy-clarke.107-175-136-137.plesk.page              plesk
# 51                    yyyahooooo.weebly.com             weebly
# 52           plansvsalvttr2.webcindario.com        webcindario
# 53       hostpoint.ch.121c0291.net2care.com           net2care
# 54                                  link.do               link
# 55                             classof1.com           classof1
# 56                           155.94.170.243     155.94.170.243
# 57                    informationcradle.com  informationcradle
# 58                                bazaar.tf             bazaar
# 59                          diamondbank.com        diamondbank
#
#                         subdomain  suffix                    domain_subdomain  \
# 40                        gitlab.      ru                       gitlab.axsoft
# 41                    dbs.mc.eu1.     com                  dbs.mc.eu1.kontiki
# 42                  anazon.co.ip.    shop                   anazon.co.ip.jpza
# 43                                    org                              schema
# 44                                     jp                                kmsk
# 45                                 com.pk                       takeonestudio
# 46               bexbadjrujjmf09.     com              bexbadjrujjmf09.weebly
# 47                                     de                         hutoknepper
# 48                                    com                   binarybenliveload
# 49                jpanamz-amanrt.     com            jpanamz-amanrt.servehttp
# 50  crazy-clarke.107-175-136-137.    page  crazy-clarke.107-175-136-137.plesk
# 51                    yyyahooooo.     com                   yyyahooooo.weebly
# 52                plansvsalvttr2.     com          plansvsalvttr2.webcindario
# 53         hostpoint.ch.121c0291.     com      hostpoint.ch.121c0291.net2care
# 54                                     do                                link
# 55                                    com                            classof1
# 56                                                             155.94.170.243
# 57                                    com                   informationcradle
# 58                                     tf                              bazaar
# 59                                    com                         diamondbank
#
#                                                  path
# 40                                                  /
# 41                                   /global2/content
# 42                                          /0p2A.php
# 43                                     /ConfirmAction
# 44           /wp-content/israel/dhlil/rwoaopt102154s/
# 45     /mkjhgj/lkjhg/bGJ1ZGRAd2VhdmVyYnVkZGxhdy5jb20=
# 46                                                  /
# 47                          /AutoScout24%20-phone.php
# 48                       /autosz/logsession/login.php
# 49                                                  /
# 50                             /CC_POSTALE2021/bc6ea/
# 51                                                  /
# 52                                                  /
# 53                                              /ar2/
# 54                                      /redirect.php
# 55  /homework_answers/zoology/conjugation_in_param...
# 56                                                  /
# 57                                    /dallas-raines/
# 58                                                  /
# 59  /index.php/diamond-mobile-app-for-smartphones-...

# %%
data_top_urls.head(20)
# Out:
#               url  phishing     domain
# 0      google.com       0.0     google
# 1     youtube.com       0.0    youtube
# 2    facebook.com       0.0   facebook
# 3       baidu.com       0.0      baidu
# 4   wikipedia.org       0.0  wikipedia
# 5       yahoo.com       0.0      yahoo
# 6    google.co.in       0.0     google
# 7      reddit.com       0.0     reddit
# 8          qq.com       0.0         qq
# 9      amazon.com       0.0     amazon
# 10     taobao.com       0.0     taobao
# 11    twitter.com       0.0    twitter
# 12      tmall.com       0.0      tmall
# 13   google.co.jp       0.0     google
# 14       live.com       0.0       live
# 15         vk.com       0.0         vk
# 16  instagram.com       0.0  instagram
# 17       sohu.com       0.0       sohu
# 18    sina.com.cn       0.0       sina
# 19         jd.com       0.0         jd

# %%
data_top_urls['domain']
# Out:
# 0             google
# 1            youtube
# 2           facebook
# 3              baidu
# 4          wikipedia
#             ...
# 4995           uspto
# 4996         elastic
# 4997           vkmag
# 4998           mtime
# 4999    mercadolibre
# Name: domain, Length: 5000, dtype: object

# %%
metric_domains = ['amazon', 'google', 'whatsapp', 'instagram', 'twitter', 'facebook', 'yahoo', 'wikipedia']

for domain in metric_domains:
    data_model['metric_'+domain] = data_model['domain_subdomain'].apply(lambda x: jellyfish.jaro_winkler(x, domain))

# %%
domain_check = 'whatsapp'
row = 0
data_model[['phishing', 'domain_subdomain', 'metric_'+domain_check, 'url']].sort_values('metric_'+domain_check, ascending = False).iloc[row:row+20]
# Out:
#        phishing    domain_subdomain  metric_whatsapp  \
# 3133        0.0            whatsapp         1.000000
# 40382       0.0            whatsapp         1.000000
# 24778       0.0            whatsapp         1.000000
# 50344       0.0        whatsappturk         0.933333
# 55521       0.0       whatsapp-free         0.923077
# 38692       0.0      whatsappstatus         0.914286
# 47999       1.0      whatsapgrupbkp         0.914286
# 16703       1.0     whatsappgroupss         0.906667
# 52392       1.0    whatsapp.acmetoy         0.900000
# 17606       1.0    whatsapp-18.ikwb         0.900000
# 45133       0.0        web.whatsapp         0.900000
# 52549       0.0        web.whatsapp         0.900000
# 20564       0.0        web.whatsapp         0.900000
# 12049       0.0        web.whatsapp         0.900000
# 45137       1.0   whatsapps.mrslove         0.894118
# 32746       1.0   whatsappku.dynssl         0.894118
# 58477       1.0  whatsapp18girl.4pu         0.888889
# 26113       1.0  whatsapp90.duckdns         0.888889
# 7968        1.0       wwhatsapp1.se         0.884615
# 23457       1.0       wwhatsapp1.se         0.884615
#
#                                       url
# 3133            https://www.whatsapp.com/
# 40382  https://www.whatsapp.com/download/
# 24778             http://www.whatsapp.com
# 50344           https://whatsappturk.com/
# 55521           https://whatsapp-free.ru/
# 38692    https://www.whatsappstatus.info/
# 47999     https://www.whatsapgrupbkp.xyz/
# 16703         http://whatsappgroupss.com/
# 52392   https://www.whatsapp.acmetoy.com/
# 17606    http://www.whatsapp-18.ikwb.com/
# 45133       https://web.whatsapp.com/🌐/ca
# 52549       https://web.whatsapp.com/🌐/cs
# 20564       https://web.whatsapp.com/🌐/ru
# 12049       https://web.whatsapp.com/🌐/tr
# 45137       http://whatsapps.mrslove.com/
# 32746  https://www.whatsappku.dynssl.com/
# 58477      http://whatsapp18girl.4pu.com/
# 26113     https://whatsapp90.duckdns.org/
# 7968            https://wwhatsapp1.se.ke/
# 23457       https://www.wwhatsapp1.se.ke/

# %% [markdown]
# # Data Final
#
# Eliminamos las variables originales que poseen strings para quedarnos solamente con las variables creadas.

# %%
data_final = data_model.drop(['url', 'scheme', 'domain_complete', 'domain', 'subdomain','suffix', 'domain_subdomain', 'suffix2'], axis = 1)

# %%
data_final
# Out:
#        phishing                                               path  \
# 0           1.0                                /inter/projet/open/
# 1           1.0  /musicgiftsgalore.com/wp-admin/js/widgets/upgr...
# 2           0.0                               /profile_center.aspx
# 3           0.0                                    /privacy_policy
# 4           1.0                                          /404.html
# ...         ...                                                ...
# 59322       1.0                                                  /
# 59323       1.0             /gwisalltrack_web/making_a_payment.htm
# 59324       0.0                                               /css
# 59325       0.0                      /michigan-vs-ohio-state-2015/
# 59326       1.0
#
#        dom_n_puntos  dom_n_guion  dom_n_guionbajo  dom_len_tot  dom_len  \
# 0                 3            0                0           10       10
# 1                 0            0                0           18       18
# 2                 2            0                0           21        9
# 3                 0            0                0           13       13
# 4                 1            1                0           18        8
# ...             ...          ...              ...          ...      ...
# 59322             0            0                0            6        6
# 59323             0            0                0           12       12
# 59324             1            0                0           16       10
# 59325             0            0                0           12       12
# 59326             1            1                0           18       11
#
#        dom_len_sub  dom_vocales  dom_cons  ...  suf_ru  suf_xyz  \
# 0                0            0         0  ...       0        0
# 1                0            7        11  ...       0        0
# 2               12            7        12  ...       0        0
# 3                0            4         7  ...       0        0
# 4               10            6        10  ...       0        0
# ...            ...          ...       ...  ...     ...      ...
# 59322            0            3         2  ...       0        0
# 59323            0            3         9  ...       0        0
# 59324            6            6         9  ...       0        0
# 59325            0            5         5  ...       0        0
# 59326            7            5        11  ...       0        0
#
#        metric_amazon  metric_google  metric_whatsapp  metric_instagram  \
# 0           0.000000       0.000000         0.000000          0.000000
# 1           0.444444       0.314815         0.402778          0.579365
# 2           0.309524       0.476190         0.448413          0.461640
# 3           0.495726       0.495726         0.000000          0.458689
# 4           0.866667       0.407407         0.574074          0.472222
# ...              ...            ...              ...               ...
# 59322       0.444444       0.555556         0.430556          0.425926
# 59323       0.416667       0.500000         0.613889          0.691799
# 59324       0.486111       0.736111         0.583333          0.556019
# 59325       0.500000       0.472222         0.000000          0.462963
# 59326       0.444444       0.444444         0.393519          0.277778
#
#        metric_twitter  metric_facebook  metric_yahoo  metric_wikipedia
# 0            0.000000         0.000000      0.000000          0.000000
# 1            0.420635         0.402778      0.418519          0.544444
# 2            0.412698         0.480159      0.415873          0.595238
# 3            0.479853         0.435897      0.425641          0.396011
# 4            0.000000         0.453704      0.503704          0.277778
# ...               ...              ...           ...               ...
# 59322        0.000000         0.430556      0.455556          0.425926
# 59323        0.634921         0.472222      0.427778          0.527778
# 59324        0.470238         0.520833      0.508333          0.395833
# 59325        0.484127         0.472222      0.427778          0.416667
# 59326        0.399471         0.402778      0.503704          0.388889
#
# [59311 rows x 30 columns]

# %% [markdown]
# ## Prueba Con Modelos

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from ModelCompare import modelCompareClass

# %%
X = data_final.drop('phishing', axis = 1)
Y = data_final['phishing']

X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size = 0.8, random_state = 42, stratify = Y)

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5496/2538021705.py in <module>
#       1 rf = RandomForestClassifier()
# ----> 2 rf.fit(X_train, y_train)
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     302                 "sparse multilabel-indicator for y is not supported."
#     303             )
# --> 304         X, y = self._validate_data(X, y, multi_output=True,
#     305                                    accept_sparse="csc", dtype=DTYPE)
#     306         if sample_weight is not None:
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869         raise ValueError("y cannot be None")
#     870
# --> 871     X = check_array(X, accept_sparse=accept_sparse,
#     872                     accept_large_sparse=accept_large_sparse,
#     873                     dtype=dtype, order=order, copy=copy,
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1988
#    1989     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1990         return np.asarray(self._values, dtype=dtype)
#    1991
#    1992     def __array_wrap__(
#
# ValueError: could not convert string to float: '/a.php'

# %%
svm = SVC()
svm.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5496/3176949710.py in <module>
#       1 svm = SVC()
# ----> 2 svm.fit(X_train, y_train)
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     167             check_consistent_length(X, y)
#     168         else:
# --> 169             X, y = self._validate_data(X, y, dtype=np.float64,
#     170                                        order='C', accept_sparse='csr',
#     171                                        accept_large_sparse=False)
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869         raise ValueError("y cannot be None")
#     870
# --> 871     X = check_array(X, accept_sparse=accept_sparse,
#     872                     accept_large_sparse=accept_large_sparse,
#     873                     dtype=dtype, order=order, copy=copy,
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1988
#    1989     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1990         return np.asarray(self._values, dtype=dtype)
#    1991
#    1992     def __array_wrap__(
#
# ValueError: could not convert string to float: '/a.php'

# %%
Comparison = modelCompareClass()

# %%
Comparison.modelReportClass('RandomForest', rf, X_train, y_train, X_test, y_test, classReport=True)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5496/3893695711.py in <module>
# ----> 1 Comparison.modelReportClass('RandomForest', rf, X_train, y_train, X_test, y_test, classReport=True)
#
# ~\Documents\GitHub\Proyecto_CDD\Proyecto A\00 - Creación Dataset y Variables\ModelCompare.py in modelReportClass(self, name, model, X_train, y_train, X_test, y_test, heatmap, ROC, classReport, addModel, probas)
#     105     ### Se puede agregar un argumento para hacer addModel directamente.
#     106     def modelReportClass(self, name, model, X_train, y_train, X_test, y_test, heatmap = True, ROC = True, classReport = False, addModel = False, probas = True):
# --> 107         metrics = self.__metricsCalculation(model, X_train, y_train, X_test, y_test, probas = probas)
#     108
#     109         print(f'------------{name}------------\n')
#
# ~\Documents\GitHub\Proyecto_CDD\Proyecto A\00 - Creación Dataset y Variables\ModelCompare.py in __metricsCalculation(self, model, X_train, y_train, X_test, y_test, probas)
#      20     # Devuelve un diccionario con las métricas.
#      21     def __metricsCalculation(self, model, X_train, y_train, X_test, y_test, probas = True):
# ---> 22         y_train_pred = model.predict(X_train)
#      23         y_test_pred = model.predict(X_test)
#      24
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     628             The predicted classes.
#     629         """
# --> 630         proba = self.predict_proba(X)
#     631
#     632         if self.n_outputs_ == 1:
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     670             classes corresponds to that in the attribute :term:`classes_`.
#     671         """
# --> 672         check_is_fitted(self)
#     673         # Check data
#     674         X = self._validate_X_predict(X)
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1096
#    1097     if not attrs:
# -> 1098         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1099
#    1100
#
# NotFittedError: This RandomForestClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
Comparison.modelReportClass('RandomForest', rf, X_train, y_train, X_test, y_test, classReport=True)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5496/3893695711.py in <module>
# ----> 1 Comparison.modelReportClass('RandomForest', rf, X_train, y_train, X_test, y_test, classReport=True)
#
# ~\Documents\GitHub\Proyecto_CDD\Proyecto A\00 - Creación Dataset y Variables\ModelCompare.py in modelReportClass(self, name, model, X_train, y_train, X_test, y_test, heatmap, ROC, classReport, addModel, probas)
#     105     ### Se puede agregar un argumento para hacer addModel directamente.
#     106     def modelReportClass(self, name, model, X_train, y_train, X_test, y_test, heatmap = True, ROC = True, classReport = False, addModel = False, probas = True):
# --> 107         metrics = self.__metricsCalculation(model, X_train, y_train, X_test, y_test, probas = probas)
#     108
#     109         print(f'------------{name}------------\n')
#
# ~\Documents\GitHub\Proyecto_CDD\Proyecto A\00 - Creación Dataset y Variables\ModelCompare.py in __metricsCalculation(self, model, X_train, y_train, X_test, y_test, probas)
#      20     # Devuelve un diccionario con las métricas.
#      21     def __metricsCalculation(self, model, X_train, y_train, X_test, y_test, probas = True):
# ---> 22         y_train_pred = model.predict(X_train)
#      23         y_test_pred = model.predict(X_test)
#      24
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     628             The predicted classes.
#     629         """
# --> 630         proba = self.predict_proba(X)
#     631
#     632         if self.n_outputs_ == 1:
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     670             classes corresponds to that in the attribute :term:`classes_`.
#     671         """
# --> 672         check_is_fitted(self)
#     673         # Check data
#     674         X = self._validate_X_predict(X)
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1096
#    1097     if not attrs:
# -> 1098         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1099
#    1100
#
# NotFittedError: This RandomForestClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
Comparison.modelReportClass('SVM', svm, X_train, y_train, X_test, y_test, ROC = False, classReport=True, probas=False)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5496/3982653418.py in <module>
# ----> 1 Comparison.modelReportClass('SVM', svm, X_train, y_train, X_test, y_test, ROC = False, classReport=True, probas=False)
#
# ~\Documents\GitHub\Proyecto_CDD\Proyecto A\00 - Creación Dataset y Variables\ModelCompare.py in modelReportClass(self, name, model, X_train, y_train, X_test, y_test, heatmap, ROC, classReport, addModel, probas)
#     105     ### Se puede agregar un argumento para hacer addModel directamente.
#     106     def modelReportClass(self, name, model, X_train, y_train, X_test, y_test, heatmap = True, ROC = True, classReport = False, addModel = False, probas = True):
# --> 107         metrics = self.__metricsCalculation(model, X_train, y_train, X_test, y_test, probas = probas)
#     108
#     109         print(f'------------{name}------------\n')
#
# ~\Documents\GitHub\Proyecto_CDD\Proyecto A\00 - Creación Dataset y Variables\ModelCompare.py in __metricsCalculation(self, model, X_train, y_train, X_test, y_test, probas)
#      20     # Devuelve un diccionario con las métricas.
#      21     def __metricsCalculation(self, model, X_train, y_train, X_test, y_test, probas = True):
# ---> 22         y_train_pred = model.predict(X_train)
#      23         y_test_pred = model.predict(X_test)
#      24
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\svm\_base.py in predict(self, X)
#     612             Class labels for samples in X.
#     613         """
# --> 614         check_is_fitted(self)
#     615         if self.break_ties and self.decision_function_shape == 'ovo':
#     616             raise ValueError("break_ties must be False when "
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\kiri\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1096
#    1097     if not attrs:
# -> 1098         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1099
#    1100
#
# NotFittedError: This SVC instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
