# %%
import pandas as pd
import numpy as np
from urllib.parse import urlparse
import tldextract

# %% [markdown]
# Usando los datasets obtenidos y generamos podemos unirlos para generar un dataset completo para la detección de phishing.

# %%
data_phish_valid = pd.read_csv('Datasets/verified_online.csv')
data_phish_valid['phishing'] = np.ones(data_phish_valid.shape[0])
data_phish_valid = data_phish_valid[['url','phishing']]
data_phish_valid
# Out:
#                                                      url  phishing
# 0          http://populaire-pro-dsp.com/PopIbet/app.html       1.0
# 1      https://talkingtree.staging-technologies.com/v...       1.0
# 2                         https://yahoopdf.yolasite.com/       1.0
# 3      https://www4.sndc-crad-nem-inedx.scottfaraday1.cn       1.0
# 4                https://annzon-ihbsf-co-jp.mbhcxy.buzz/       1.0
# ...                                                  ...       ...
# 11102                          http://gkjx168.com/images       1.0
# 11103       http://www.habbocreditosparati.blogspot.com/       1.0
# 11104  http://creditiperhabbogratissicuro100.blogspot...       1.0
# 11105  http://mundovirtualhabbo.blogspot.com/2009_01_...       1.0
# 11106  http://aijcs.blogspot.com/2005/03/colourful-li...       1.0
#
# [11107 rows x 2 columns]

# %%
data_phish_valid.iloc[60:80]
# Out:
#                                                   url  phishing
# 60  https://modest-cohen.46-20-34-168.plesk.page/r27/       1.0
# 61  http://serviceagf.temp.swtest.ru/wp-content/la...       1.0
# 62  https://socialmediamarkettiers.com/wp-kxjk/office       1.0
# 63  https://socialmediamarkettiers.com/wp-kxjk/off...       1.0
# 64             http://newxxporn-virals83.duckdns.org/       1.0
# 65  https://dennybegle.com/netbankar/mkb.hu/mkbnet...       1.0
# 66  https://dennybegle.com/netbankar/mkb.hu/mkbnet...       1.0
# 67  https://housestoneltd.com/sal/ggg/china/?login...       1.0
# 68  https://www.logobirds.com/wp-content/plugins/n...       1.0
# 69  https://www.logobirds.com/wp-content/plugins/n...       1.0
# 70  https://www.logobirds.com/wp-content/plugins/n...       1.0
# 71  https://www.logobirds.com/wp-content/plugins/n...       1.0
# 72                       https://eggbox.top/pay/error       1.0
# 73  http://www.adverisementcollectionateliergroup....       1.0
# 74  https://www.adverisementcollectionateliergroup...       1.0
# 75                             https://155.94.140.23/       1.0
# 76               http://join-grup-xxxx02.duckdns.org/       1.0
# 77               http://grup-whatsap-hot.duckdns.org/       1.0
# 78                     https://bernardo.pizza/frepil/       1.0
# 79                      http://bupsdd.com/NEW/amazon/       1.0

# %%
data_top_urls = pd.read_csv('Datasets/Dataset_Top_urls.csv')
data_top_urls = data_top_urls.iloc[:5000]
data_top_urls['phishing'] = np.zeros(data_top_urls.shape[0])
data_top_urls = data_top_urls[['URL','phishing']]
data_top_urls.columns = ['url', 'phishing']
data_top_urls
# Out:
#                       url  phishing
# 0              google.com       0.0
# 1             youtube.com       0.0
# 2            facebook.com       0.0
# 3               baidu.com       0.0
# 4           wikipedia.org       0.0
# ...                   ...       ...
# 4995            uspto.gov       0.0
# 4996           elastic.co       0.0
# 4997            vkmag.com       0.0
# 4998            mtime.com       0.0
# 4999  mercadolibre.com.pe       0.0
#
# [5000 rows x 2 columns]

# %% [markdown]
# Podríamos comparar dominios correctos usando estos top urls contra los dominios de los urls analizados.

# %%
data_top_urls['domain'] = data_top_urls['url'].apply(lambda x: tldextract.extract(x).domain)
data_top_urls.iloc[70:90]
# Out:
#                       url  phishing             domain
# 70             paypal.com       0.0             paypal
# 71    microsoftonline.com       0.0    microsoftonline
# 72          google.com.tw       0.0             google
# 73          google.com.au       0.0             google
# 74           whatsapp.com       0.0           whatsapp
# 75              google.pl       0.0             google
# 76           xhamster.com       0.0           xhamster
# 77       detail.tmall.com       0.0              tmall
# 78              diply.com       0.0              diply
# 79           google.co.id       0.0             google
# 80              adobe.com       0.0              adobe
# 81             coccoc.com       0.0             coccoc
# 82         craigslist.org       0.0         craigslist
# 83           nicovideo.jp       0.0          nicovideo
# 84               txxx.com       0.0               txxx
# 85            dropbox.com       0.0            dropbox
# 86              amazon.de       0.0             amazon
# 87          google.com.ar       0.0             google
# 88              amazon.in       0.0             amazon
# 89  googleusercontent.com       0.0  googleusercontent

# %%
data_phish_sus = pd.read_csv('Datasets/Dataset_Phishing_Total.csv')
data_phish_sus['phishing'] = np.zeros(data_phish_sus.shape[0])
data_phish_sus = data_phish_sus[['URL','phishing']]
data_phish_sus.columns = ['url', 'phishing']
data_phish_sus
# Out:
#                                                      url  phishing
# 0                     https://www.paysafecard.com/fr-ch/       0.0
# 1                                    https://cncs.gob.do       0.0
# 2                      https://eticket.migracion.gob.do/       0.0
# 3              https://www.indeed.com/legal?hl=en_US#tos       0.0
# 4                         https://www.peoplemetrics.com/       0.0
# ...                                                  ...       ...
# 10115  https://nam01.safelinks.protection.outlook.com...       0.0
# 10116  https://na01.safelinks.protection.outlook.com/...       0.0
# 10117                     http://vodafone.myinbound.com/       0.0
# 10118  https://nam03.safelinks.protection.outlook.com...       0.0
# 10119  https://na01.safelinks.protection.outlook.com/...       0.0
#
# [10120 rows x 2 columns]

# %% [markdown]
# Generamos el dataset completo y mezclamos las observaciones.

# %%
# Pruebo sin incluir top_urls
data = pd.concat([data_phish_sus, data_phish_valid])
data = data.sample(frac=1, random_state = 42).reset_index(drop=True)
#data.to_csv('Dataset_URL.csv')
data.head(10)
# Out:
#                                                  url  phishing
# 0   https://www.powr.io/form-builder/i/27476566#page       1.0
# 1  http://mjaymu1hetezmtj0aa.filesusr.com/html/c6...       1.0
# 2  https://www.google.com/webhp?sxsrf=ACYBGNSlZQV...       0.0
# 3  https://sites.google.com/view/xcccjcdhasks/btc...       1.0
# 4  http://clouddoc-authorize.firebaseapp.com/...x...       1.0
# 5  https://rule.alibaba.com/rule/detail/2041.htm?...       0.0
# 6  http://157.245.101.68/wp-admin/cs/office2020/o...       1.0
# 7                https://siemik.github.io/lp_axa_34/       1.0
# 8                                http://bit.do/fRb8y       1.0
# 9          https://itau.negocie-aqui.com/c/JWgn36iqE       0.0

# %%
data['phishing'].value_counts()
# Out:
# 1.0    11107
# 0.0    10120
# Name: phishing, dtype: int64

# %% [markdown]
# ## Variable Scheme
#
# Los 5000 urls obtenidos de alexa no tienen esta porción. Estos links podrían introducir sesgos en el análisis. Podemos analizar estos links que tienen 'spam' como scheme, pero en principio son observaciones que no se incluirían.

# %%
data['scheme'] = data['url'].apply(lambda x: urlparse(x).scheme)

# %%
data['scheme'].value_counts()
# Out:
# https    13051
# http      8162
# spams        8
# spam         6
# Name: scheme, dtype: int64

# %%
pd.crosstab(index = data['phishing'], columns = data['scheme'])
# Out:
# scheme    http  https  spam  spams
# phishing
# 0.0       3271   6835     6      8
# 1.0       4891   6216     0      0

# %% [markdown]
# ## Variable Domain

# %% [markdown]
# Extraemos el dominio completo de los urls analizados.

# %%
data['domain_complete'] = data['url'].apply(lambda x: urlparse(x).netloc)

# %% [markdown]
# Hay dos urls que no parecerían tener dominio.

# %%
(data['domain_complete'] == '').sum()
# Out:
# 2

# %%
data.head()
# Out:
#                                                  url  phishing scheme  \
# 0   https://www.powr.io/form-builder/i/27476566#page       1.0  https
# 1  http://mjaymu1hetezmtj0aa.filesusr.com/html/c6...       1.0   http
# 2  https://www.google.com/webhp?sxsrf=ACYBGNSlZQV...       0.0  https
# 3  https://sites.google.com/view/xcccjcdhasks/btc...       1.0  https
# 4  http://clouddoc-authorize.firebaseapp.com/...x...       1.0   http
#
#                       domain_complete       domain            subdomain  \
# 0                         www.powr.io         powr
# 1     mjaymu1hetezmtj0aa.filesusr.com     filesusr  mjaymu1hetezmtj0aa.
# 2                      www.google.com       google
# 3                    sites.google.com       google               sites.
# 4  clouddoc-authorize.firebaseapp.com  firebaseapp  clouddoc-authorize.
#
#   suffix                domain_subdomain  \
# 0     io                            powr
# 1    com     mjaymu1hetezmtj0aa.filesusr
# 2    com                          google
# 3    com                    sites.google
# 4    com  clouddoc-authorize.firebaseapp
#
#                                                 path
# 0                           /form-builder/i/27476566
# 1  /html/c69417_3069841d505568614ed8bca153fc7adf....
# 2                                             /webhp
# 3                       /view/xcccjcdhasks/btconnect
# 4                                  /...xxx........./

# %%
data['domain_complete']
# Out:
# 0                               www.powr.io
# 1           mjaymu1hetezmtj0aa.filesusr.com
# 2                            www.google.com
# 3                          sites.google.com
# 4        clouddoc-authorize.firebaseapp.com
#                         ...
# 21222          grubbokepnew2021.duckdns.org
# 21223     xserver-ne-jp.omegapediatrics.com
# 21224                       games-box.do.am
# 21225                   underthedoormat.com
# 21226         www.beloanvi333.byethost7.com
# Name: domain_complete, Length: 21227, dtype: object

# %% [markdown]
# Del dominio completo se puede extraer el sufijo, el dominio y el subdominio.
#
# * Con el sufijo se puede armar una variable categórica.
# * Revisar el dominio y subdominio (se podrían analizar juntos o separados).

# %%
data['domain'] = data['domain_complete'].apply(lambda x: tldextract.extract(x).domain)
data['subdomain'] = data['domain_complete'].apply(lambda x: tldextract.extract(x).subdomain)
data['suffix'] = data['domain_complete'].apply(lambda x: tldextract.extract(x).suffix)

# %% [markdown]
# Podemos eliminar los prefijos "www." de el subdomain y crear una variable de domain + subdomain. Esto se puede realizar porque "entiendo" que todos los urls se pueden escribir con o sin 'www' por lo que incluirlos en el análisis puede afectar innecesariamente.

# %%
data['subdomain'] = data['subdomain'].str.replace('www.', '')
data['subdomain'] = data['subdomain'].str.replace('www', '')

# %%
data['subdomain'] = data['subdomain'] + '.'
data['subdomain'] = data['subdomain'].replace('.', '')

# %%
data['domain_subdomain'] = data['subdomain'] + data['domain']

# %% [markdown]
# Para el sufijo se pueden generar variables categóricas incluyendo a todas las clases poco frecuentes en una categoría "Otros".

# %%
data['suffix'].value_counts()
# Out:
# com       11238
# net        1073
# ru          784
# org         770
# com.br      323
#           ...
# media         1
# ls            1
# pub           1
# nc            1
# sydney        1
# Name: suffix, Length: 386, dtype: int64

# %% [markdown]
# ## Variable Path

# %%
data['path'] = data['url'].apply(lambda x: urlparse(x).path)

# %%
print((data['path'] == '').sum())
print((data['path'] == '/').sum())
# Out:
# 899
# 5188

# %%
data['url'].str.count('\\=').value_counts()
# Out:
# 0     16006
# 1      2438
# 2       731
# 3       530
# 4       510
# 6       257
# 5       256
# 7       145
# 8        72
# 10       61
# 9        60
# 11       48
# 12       42
# 13       19
# 20       13
# 14       12
# 17        6
# 25        5
# 15        5
# 18        4
# 19        2
# 16        2
# 21        1
# 23        1
# 24        1
# Name: url, dtype: int64

# %%
# Variables del dominio
# Cuenta los puntos
data['domain_subdomain'].str.count('\\.')
data['domain_subdomain'].str.count('\\-')
# Cuenta el largo
data['domain_subdomain'].str.len()
# Cuenta vocales
data['domain_subdomain'].str.lower().str.count(r'[aeiou]')
# Cuenta consonantes
data['domain_subdomain'].str.lower().str.count(r'[a-z]') - data['domain_vocales']
# Cuenta números
data['domain_subdomain'].str.count('\d')
# Out:
# 0     17232
# 1      1089
# 2       740
# 3       611
# 4       355
# 6       218
# 7       160
# 10      153
# 5       144
# 8       109
# 12      106
# 11      103
# 9        87
# 13       19
# 14       17
# 15       14
# 22       13
# 27       12
# 21        9
# 19        8
# 18        6
# 23        5
# 28        3
# 17        3
# 20        2
# 34        2
# 16        2
# 24        1
# 36        1
# 25        1
# 30        1
# 31        1
# Name: domain_subdomain, dtype: int64

# %%
data['domain_subdomain'].str.count('\\.').value_counts()
# Out:
# 0     12174
# 1      6790
# 2      1058
# 3       728
# 5       238
# 6       148
# 4        87
# 10        2
# 7         1
# 18        1
# Name: domain_subdomain, dtype: int64

# %%
data.iloc[40:60]
# Out:
#                                                   url  phishing scheme  \
# 40                             https://vipchanger.com       0.0  https
# 41                      http://myee-billing-info.com/       1.0   http
# 42                      http://bupsdd.com/NEW/amazon/       1.0   http
# 43                      http://servernuovaintesa.com/       1.0   http
# 44                https://www.disneyworld.eu/profile/       0.0  https
# 45        https://www.orange.jo/ar/pages/default.aspx       0.0  https
# 46       https://www.m.psservlces.runescape.com-m.ru/       1.0  https
# 47  https://www.proprofs.com/survey/preview.php?ti...       1.0  https
# 48                             http://192.254.66.115/       0.0   http
# 49  https://support.arcticwolf.com/attachments/tok...       0.0  https
# 50  https://accounts.google.com/ServiceLogin?servi...       1.0  https
# 51  http://www.readbag.com/cdphe-state-us-pp-injur...       0.0   http
# 52       http://en.riotpixels.com/games/honey-select/       0.0   http
# 53       http://alias.com.br/tag/cidades-sustentaveis       0.0   http
# 54                                  https://ee.co.uk/       0.0  https
# 55                          http://www.revmatesv.com/       0.0   http
# 56                              http://www.synaq.com/       0.0   http
# 57                 https://vevobahisbet.blogspot.com/       1.0  https
# 58  https://sixpointpartners-my.sharepoint.com/per...       1.0  https
# 59  http://bookslists.com/book/20325/The-Golems-of...       0.0   http
#
#                         domain_complete             domain  \
# 40                       vipchanger.com         vipchanger
# 41                myee-billing-info.com  myee-billing-info
# 42                           bupsdd.com             bupsdd
# 43                servernuovaintesa.com  servernuovaintesa
# 44                   www.disneyworld.eu        disneyworld
# 45                        www.orange.jo             orange
# 46  www.m.psservlces.runescape.com-m.ru              com-m
# 47                     www.proprofs.com           proprofs
# 48                       192.254.66.115     192.254.66.115
# 49               support.arcticwolf.com         arcticwolf
# 50                  accounts.google.com             google
# 51                      www.readbag.com            readbag
# 52                    en.riotpixels.com         riotpixels
# 53                         alias.com.br              alias
# 54                             ee.co.uk                 ee
# 55                    www.revmatesv.com          revmatesv
# 56                        www.synaq.com              synaq
# 57            vevobahisbet.blogspot.com           blogspot
# 58   sixpointpartners-my.sharepoint.com         sharepoint
# 59                       bookslists.com         bookslists
#
#                   subdomain  suffix                domain_subdomain  \
# 40                              com                      vipchanger
# 41                              com               myee-billing-info
# 42                              com                          bupsdd
# 43                              com               servernuovaintesa
# 44                               eu                     disneyworld
# 45                               jo                          orange
# 46  m.psservlces.runescape.      ru    m.psservlces.runescape.com-m
# 47                              com                        proprofs
# 48                                                   192.254.66.115
# 49                 support.     com              support.arcticwolf
# 50                accounts.     com                 accounts.google
# 51                              com                         readbag
# 52                      en.     com                   en.riotpixels
# 53                           com.br                           alias
# 54                            co.uk                              ee
# 55                              com                       revmatesv
# 56                              com                           synaq
# 57            vevobahisbet.     com           vevobahisbet.blogspot
# 58     sixpointpartners-my.     com  sixpointpartners-my.sharepoint
# 59                              com                      bookslists
#
#                                                  path  metric_amazon  \
# 40                                                          0.511111
# 41                                                  /       0.483660
# 42                                       /NEW/amazon/       0.000000
# 43                                                  /       0.316993
# 44                                          /profile/       0.338384
# 45                             /ar/pages/default.aspx       0.555556
# 46                                                  /       0.468254
# 47                                /survey/preview.php       0.430556
# 48                                                  /       0.000000
# 49      /attachments/token/vWE7IepA5YfH7mkeignKMyZTO/       0.314815
# 50                                      /ServiceLogin       0.566667
# 51            /cdphe-state-us-pp-injuryprevention-w-9       0.436508
# 52                               /games/honey-select/       0.329060
# 53                          /tag/cidades-sustentaveis       0.577778
# 54                                                  /       0.000000
# 55                                                  /       0.518519
# 56                                                  /       0.455556
# 57                                                  /       0.309524
# 58  /personal/alorusso_sixpointpartners_com/_layou...       0.422222
# 59           /book/20325/The-Golems-of-Gotham-A-Novel       0.422222
#
#     metric_paypal  metric_whatsapp  metric_google  metric_instagram  \
# 40       0.511111         0.447222       0.511111          0.614815
# 41       0.483660         0.000000       0.316993          0.446623
# 42       0.444444         0.430556       0.000000          0.425926
# 43       0.408497         0.455882       0.316993          0.393246
# 44       0.505051         0.405303       0.419192          0.519360
# 45       0.444444         0.430556       0.666667          0.500000
# 46       0.468254         0.382937       0.301587          0.362434
# 47       0.527778         0.333333       0.527778          0.412037
# 48       0.000000         0.000000       0.000000          0.000000
# 49       0.444444         0.500926       0.407407          0.472222
# 50       0.411111         0.525000       0.488889          0.562963
# 51       0.539683         0.511905       0.000000          0.476190
# 52       0.414530         0.467949       0.329060          0.417379
# 53       0.577778         0.547222       0.000000          0.533333
# 54       0.000000         0.000000       0.000000          0.000000
# 55       0.425926         0.569444       0.425926          0.314815
# 56       0.411111         0.441667       0.000000          0.533333
# 57       0.476190         0.396825       0.309524          0.378307
# 58       0.422222         0.463889       0.466667          0.622751
# 59       0.422222         0.408333       0.600000          0.403704
#
#     metric_twitter  metric_facebook  metric_yahoo
# 40        0.576190         0.316667      0.366667
# 41        0.301120         0.455882      0.419608
# 42        0.000000         0.000000      0.000000
# 43        0.467787         0.455882      0.419608
# 44        0.567100         0.477273      0.430303
# 45        0.436508         0.527778      0.455556
# 46        0.452381         0.273810      0.000000
# 47        0.422619         0.500000      0.550000
# 48        0.000000         0.000000      0.000000
# 49        0.420635         0.402778      0.337037
# 50        0.403175         0.588889      0.600000
# 51        0.000000         0.490079      0.447619
# 52        0.459707         0.467949      0.425641
# 53        0.447619         0.441667      0.466667
# 54        0.000000         0.541667      0.000000
# 55        0.502646         0.324074      0.437037
# 56        0.000000         0.441667      0.466667
# 57        0.412698         0.554365      0.469841
# 58        0.493651         0.380556      0.322222
# 59        0.495238         0.633333      0.533333

# %% [markdown]
# # Prueba Distancia de Strings

# %%
import jellyfish

# %% [markdown]
# Link de la documentación de la libreria.
#
# https://jellyfish.readthedocs.io/en/latest/comparison.html
#
# Link de la explicación de Jaro Distance.
#
# https://en.wikipedia.org/wiki/Jaro%E2%80%93Winkler_distance

# %%
links_url = [
                'amazon.com', 
                'amazon.co.safeamazonsecure.icu', 
                'aoinamozm.servebeer.com', 
                'breakevents.de', 
                'spectralwirejewelry.com', 
                'eim.ae.iwc.static.royalgatetransport.ae',
                'www.amazonlogistics.eu',
                'www.amazon.fr'
            ]

for link in links_url:
    print(tldextract.extract(link))
# Out:
# ExtractResult(subdomain='', domain='amazon', suffix='com')
# ExtractResult(subdomain='amazon.co', domain='safeamazonsecure', suffix='icu')
# ExtractResult(subdomain='aoinamozm', domain='servebeer', suffix='com')
# ExtractResult(subdomain='', domain='breakevents', suffix='de')
# ExtractResult(subdomain='', domain='spectralwirejewelry', suffix='com')
# ExtractResult(subdomain='eim.ae.iwc.static', domain='royalgatetransport', suffix='ae')
# ExtractResult(subdomain='www', domain='amazonlogistics', suffix='eu')
# ExtractResult(subdomain='www', domain='amazon', suffix='fr')

# %% [markdown]
# La mejor métrica de similitud entre strings parece ser la distancia Jaro - Winkler.

# %%
for link in links_url:
    print(f'Link: {link} - metric {jellyfish.jaro_distance(tldextract.extract(link).domain+tldextract.extract(link).subdomain, "amazon")}')
# Out:
# Link: amazon.com - metric 1.0
# Link: amazon.co.safeamazonsecure.icu - metric 0.6911111111111111
# Link: aoinamozm.servebeer.com - metric 0.5555555555555555
# Link: breakevents.de - metric 0.5050505050505051
# Link: spectralwirejewelry.com - metric 0.4064327485380117
# Link: eim.ae.iwc.static.royalgatetransport.ae - metric 0.5103174603174603
# Link: www.amazonlogistics.eu - metric 0.7777777777777777
# Link: www.amazon.fr - metric 0.8888888888888888

# %%
for link in links_url:
    print(f'Link: {link} - metric {jellyfish.jaro_winkler(tldextract.extract(link).domain+tldextract.extract(link).subdomain, "amazon")}')
# Out:
# Link: amazon.com - metric 1.0
# Link: amazon.co.safeamazonsecure.icu - metric 0.6911111111111111
# Link: aoinamozm.servebeer.com - metric 0.5555555555555555
# Link: breakevents.de - metric 0.5050505050505051
# Link: spectralwirejewelry.com - metric 0.4064327485380117
# Link: eim.ae.iwc.static.royalgatetransport.ae - metric 0.5103174603174603
# Link: www.amazonlogistics.eu - metric 0.8666666666666666
# Link: www.amazon.fr - metric 0.9333333333333333

# %%
for link in links_url:
    print(f'Link: {link} - metric {jellyfish.hamming_distance(link, "amazon.com")}')
# Out:
# Link: amazon.com - metric 0
# Link: amazon.co.safeamazonsecure.icu - metric 21
# Link: aoinamozm.servebeer.com - metric 22
# Link: breakevents.de - metric 14
# Link: spectralwirejewelry.com - metric 23
# Link: eim.ae.iwc.static.royalgatetransport.ae - metric 38
# Link: www.amazonlogistics.eu - metric 21
# Link: www.amazon.fr - metric 12

# %%
for link in links_url:
    print(f'Link: {link} - metric {jellyfish.levenshtein_distance(link, "amazon.com")}')
# Out:
# Link: amazon.com - metric 0
# Link: amazon.co.safeamazonsecure.icu - metric 20
# Link: aoinamozm.servebeer.com - metric 16
# Link: breakevents.de - metric 12
# Link: spectralwirejewelry.com - metric 18
# Link: eim.ae.iwc.static.royalgatetransport.ae - metric 34
# Link: www.amazonlogistics.eu - metric 15
# Link: www.amazon.fr - metric 7

# %%
for link in links_url:
    print(f'Link: {link} - metric {jellyfish.damerau_levenshtein_distance(link, "amazon.com")}')
# Out:
# Link: amazon.com - metric 0
# Link: amazon.co.safeamazonsecure.icu - metric 20
# Link: aoinamozm.servebeer.com - metric 16
# Link: breakevents.de - metric 12
# Link: spectralwirejewelry.com - metric 18
# Link: eim.ae.iwc.static.royalgatetransport.ae - metric 34
# Link: www.amazonlogistics.eu - metric 15
# Link: www.amazon.fr - metric 7

# %%
print(jellyfish.jaro_distance('amazon.com', 'amazon.com'))
print(jellyfish.jaro_distance('amazon.co.safeamazonsecure.icu', 'amazon.com'))
print(jellyfish.jaro_distance('aoinamozm.servebeer.com', 'amazon.com'))
print(jellyfish.jaro_distance('breakevents.de', 'amazon.com'))
print(jellyfish.jaro_distance('spectralwirejewelry.com', 'amazon.com'))
print(jellyfish.jaro_distance('eim.ae.iwc.static.royalgatetransport.ae', 'amazon.com'))
print(jellyfish.jaro_distance('amazon.co.jp', 'amazon.com'))
print(jellyfish.jaro_distance('www.amazonlogistics.eu', 'amazon.com'))
print(jellyfish.jaro_distance('www.amazon.fr', 'amazon.com'))
# Out:
# 1.0
# 0.7777777777777777
# 0.6156199677938808
# 0.5047619047619047
# 0.26231884057971017
# 0.47350427350427343
# 0.8833333333333333
# 0.6215488215488215
# 0.6032967032967033

# %%
row = 40
data.iloc[row:row+20]
# Out:
#                                                   url  phishing scheme  \
# 40                             https://vipchanger.com       0.0  https
# 41                      http://myee-billing-info.com/       1.0   http
# 42                      http://bupsdd.com/NEW/amazon/       1.0   http
# 43                      http://servernuovaintesa.com/       1.0   http
# 44                https://www.disneyworld.eu/profile/       0.0  https
# 45        https://www.orange.jo/ar/pages/default.aspx       0.0  https
# 46       https://www.m.psservlces.runescape.com-m.ru/       1.0  https
# 47  https://www.proprofs.com/survey/preview.php?ti...       1.0  https
# 48                             http://192.254.66.115/       0.0   http
# 49  https://support.arcticwolf.com/attachments/tok...       0.0  https
# 50  https://accounts.google.com/ServiceLogin?servi...       1.0  https
# 51  http://www.readbag.com/cdphe-state-us-pp-injur...       0.0   http
# 52       http://en.riotpixels.com/games/honey-select/       0.0   http
# 53       http://alias.com.br/tag/cidades-sustentaveis       0.0   http
# 54                                  https://ee.co.uk/       0.0  https
# 55                          http://www.revmatesv.com/       0.0   http
# 56                              http://www.synaq.com/       0.0   http
# 57                 https://vevobahisbet.blogspot.com/       1.0  https
# 58  https://sixpointpartners-my.sharepoint.com/per...       1.0  https
# 59  http://bookslists.com/book/20325/The-Golems-of...       0.0   http
#
#                         domain_complete             domain  \
# 40                       vipchanger.com         vipchanger
# 41                myee-billing-info.com  myee-billing-info
# 42                           bupsdd.com             bupsdd
# 43                servernuovaintesa.com  servernuovaintesa
# 44                   www.disneyworld.eu        disneyworld
# 45                        www.orange.jo             orange
# 46  www.m.psservlces.runescape.com-m.ru              com-m
# 47                     www.proprofs.com           proprofs
# 48                       192.254.66.115     192.254.66.115
# 49               support.arcticwolf.com         arcticwolf
# 50                  accounts.google.com             google
# 51                      www.readbag.com            readbag
# 52                    en.riotpixels.com         riotpixels
# 53                         alias.com.br              alias
# 54                             ee.co.uk                 ee
# 55                    www.revmatesv.com          revmatesv
# 56                        www.synaq.com              synaq
# 57            vevobahisbet.blogspot.com           blogspot
# 58   sixpointpartners-my.sharepoint.com         sharepoint
# 59                       bookslists.com         bookslists
#
#                   subdomain  suffix                domain_subdomain  \
# 40                              com                      vipchanger
# 41                              com               myee-billing-info
# 42                              com                          bupsdd
# 43                              com               servernuovaintesa
# 44                               eu                     disneyworld
# 45                               jo                          orange
# 46  m.psservlces.runescape.      ru    m.psservlces.runescape.com-m
# 47                              com                        proprofs
# 48                                                   192.254.66.115
# 49                 support.     com              support.arcticwolf
# 50                accounts.     com                 accounts.google
# 51                              com                         readbag
# 52                      en.     com                   en.riotpixels
# 53                           com.br                           alias
# 54                            co.uk                              ee
# 55                              com                       revmatesv
# 56                              com                           synaq
# 57            vevobahisbet.     com           vevobahisbet.blogspot
# 58     sixpointpartners-my.     com  sixpointpartners-my.sharepoint
# 59                              com                      bookslists
#
#                                                  path  metric_amazon  \
# 40                                                          0.511111
# 41                                                  /       0.483660
# 42                                       /NEW/amazon/       0.000000
# 43                                                  /       0.316993
# 44                                          /profile/       0.338384
# 45                             /ar/pages/default.aspx       0.555556
# 46                                                  /       0.468254
# 47                                /survey/preview.php       0.430556
# 48                                                  /       0.000000
# 49      /attachments/token/vWE7IepA5YfH7mkeignKMyZTO/       0.314815
# 50                                      /ServiceLogin       0.566667
# 51            /cdphe-state-us-pp-injuryprevention-w-9       0.436508
# 52                               /games/honey-select/       0.329060
# 53                          /tag/cidades-sustentaveis       0.577778
# 54                                                  /       0.000000
# 55                                                  /       0.518519
# 56                                                  /       0.455556
# 57                                                  /       0.309524
# 58  /personal/alorusso_sixpointpartners_com/_layou...       0.422222
# 59           /book/20325/The-Golems-of-Gotham-A-Novel       0.422222
#
#     metric_paypal  metric_whatsapp  metric_google  metric_instagram  \
# 40       0.511111         0.447222       0.511111          0.614815
# 41       0.483660         0.000000       0.316993          0.446623
# 42       0.444444         0.430556       0.000000          0.425926
# 43       0.408497         0.455882       0.316993          0.393246
# 44       0.505051         0.405303       0.419192          0.519360
# 45       0.444444         0.430556       0.666667          0.500000
# 46       0.468254         0.382937       0.301587          0.362434
# 47       0.527778         0.333333       0.527778          0.412037
# 48       0.000000         0.000000       0.000000          0.000000
# 49       0.444444         0.500926       0.407407          0.472222
# 50       0.411111         0.525000       0.488889          0.562963
# 51       0.539683         0.511905       0.000000          0.476190
# 52       0.414530         0.467949       0.329060          0.417379
# 53       0.577778         0.547222       0.000000          0.533333
# 54       0.000000         0.000000       0.000000          0.000000
# 55       0.425926         0.569444       0.425926          0.314815
# 56       0.411111         0.441667       0.000000          0.533333
# 57       0.476190         0.396825       0.309524          0.378307
# 58       0.422222         0.463889       0.466667          0.622751
# 59       0.422222         0.408333       0.600000          0.403704
#
#     metric_twitter  metric_facebook  metric_yahoo
# 40        0.576190         0.316667      0.366667
# 41        0.301120         0.455882      0.419608
# 42        0.000000         0.000000      0.000000
# 43        0.467787         0.455882      0.419608
# 44        0.567100         0.477273      0.430303
# 45        0.436508         0.527778      0.455556
# 46        0.452381         0.273810      0.000000
# 47        0.422619         0.500000      0.550000
# 48        0.000000         0.000000      0.000000
# 49        0.420635         0.402778      0.337037
# 50        0.403175         0.588889      0.600000
# 51        0.000000         0.490079      0.447619
# 52        0.459707         0.467949      0.425641
# 53        0.447619         0.441667      0.466667
# 54        0.000000         0.541667      0.000000
# 55        0.502646         0.324074      0.437037
# 56        0.000000         0.441667      0.466667
# 57        0.412698         0.554365      0.469841
# 58        0.493651         0.380556      0.322222
# 59        0.495238         0.633333      0.533333

# %%
data_top_urls.head(20)
# Out:
#               url  phishing     domain
# 0      google.com       0.0     google
# 1     youtube.com       0.0    youtube
# 2    facebook.com       0.0   facebook
# 3       baidu.com       0.0      baidu
# 4   wikipedia.org       0.0  wikipedia
# 5       yahoo.com       0.0      yahoo
# 6    google.co.in       0.0     google
# 7      reddit.com       0.0     reddit
# 8          qq.com       0.0         qq
# 9      amazon.com       0.0     amazon
# 10     taobao.com       0.0     taobao
# 11    twitter.com       0.0    twitter
# 12      tmall.com       0.0      tmall
# 13   google.co.jp       0.0     google
# 14       live.com       0.0       live
# 15         vk.com       0.0         vk
# 16  instagram.com       0.0  instagram
# 17       sohu.com       0.0       sohu
# 18    sina.com.cn       0.0       sina
# 19         jd.com       0.0         jd

# %%
data_top_urls['domain']
# Out:
# 0             google
# 1            youtube
# 2           facebook
# 3              baidu
# 4          wikipedia
#             ...
# 4995           uspto
# 4996         elastic
# 4997           vkmag
# 4998           mtime
# 4999    mercadolibre
# Name: domain, Length: 5000, dtype: object

# %%
metric_domains = ['amazon', 'google', 'whatsapp', 'instagram', 'twitter', 'facebook', 'yahoo']

for domain in metric_domains:
    data['metric_'+domain] = data['domain_subdomain'].apply(lambda x: jellyfish.jaro_distance(x, domain))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'domain_subdomain'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-59001c55016e> in <module>
#       2
#       3 for domain in metric_domains:
# ----> 4     data['metric_'+domain] = data['domain_subdomain'].apply(lambda x: jellyfish.jaro_distance(x, domain))
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'domain_subdomain'

# %%
domain_check = 'whatsapp'
row = 20
data[['phishing', 'domain_subdomain', 'metric_'+domain_check, 'url']].sort_values('metric_'+domain_check, ascending = False).iloc[row:row+20]
# Out:
#        phishing                  domain_subdomain  metric_whatsapp  \
# 7402        1.0            join-whatsappk8wh.xxuz         0.787879
# 2788        1.0           whatsapp-grup93.duckdns         0.782609
# 21169       1.0                           alsnapp         0.779762
# 15377       1.0          whatshapgrup2021.duckdns         0.777778
# 546         0.0         whatsapp.fr.downloadastro         0.773333
# 10555       1.0                 join-whatapp.otzo         0.762255
# 10163       1.0      grubwhatsapp-hot2021.duckdns         0.761905
# 15486       1.0      grub-whatsapp18viral.duckdns         0.761905
# 5812        0.0     whatsapp-recovery.en.softonic         0.758621
# 13636       0.0    whatsapp-messenger.id.uptodown         0.755556
# 13343       0.0    whatsapp-messenger.en.uptodown         0.755556
# 14443       1.0   whatsappjointogroup2021.duckdns         0.752688
# 537         1.0   whatsappjointogroup2021.duckdns         0.752688
# 18901       1.0  whatsapp-chatjoingrubnew.duckdns         0.750000
# 7410        0.0                          whatsism         0.750000
# 7434        1.0  whatsappinffocerotvdhd19.duckdns         0.750000
# 1514        0.0                      whatstracker         0.750000
# 14033       0.0                      whatstracker         0.750000
# 13340       1.0                                ht         0.750000
# 14259       0.0                         thaidapps         0.750000
#
#                                                      url
# 7402                  http://join-whatsappk8wh.xxuz.com/
# 2788                https://whatsapp-grup93.duckdns.org/
# 21169                         http://www.alsnapp.com/AF/
# 15377               http://whatshapgrup2021.duckdns.org/
# 546               https://whatsapp.fr.downloadastro.com/
# 10555                  http://www.join-whatapp.otzo.com/
# 10163           http://grubwhatsapp-hot2021.duckdns.org/
# 15486           http://grub-whatsapp18viral.duckdns.org/
# 5812          https://whatsapp-recovery.en.softonic.com/
# 13636  https://whatsapp-messenger.id.uptodown.com/and...
# 13343  https://whatsapp-messenger.en.uptodown.com/and...
# 14443        http://whatsappjointogroup2021.duckdns.org/
# 537     https://www.whatsappjointogroup2021.duckdns.org/
# 18901      https://whatsapp-chatjoingrubnew.duckdns.org/
# 7410         https://whatsism.com/6-whatsapp-for-pc.html
# 7434       https://whatsappinffocerotvdhd19.duckdns.org/
# 1514                       https://www.whatstracker.org/
# 14033                            http://whatstracker.org
# 13340                           http://ht.ly/XZ2130raXCW
# 14259             http://thaidapps.com/feed/tags/ordered

# %%
data[['phishing', 'domain_subdomain', 'metric_whatsapp']].sort_values('metric_whatsapp', ascending = False).iloc[0:20]
# Out:
#        phishing       domain_subdomain  metric_whatsapp
# 16250       0.0               whatsapp         1.000000
# 11044       0.0               whatsapp         1.000000
# 3357        0.0           whatsappturk         0.888889
# 5737        0.0           web.whatsapp         0.888889
# 14747       0.0           web.whatsapp         0.888889
# 20315       0.0           web.whatsapp         0.888889
# 2153        0.0           web.whatsapp         0.888889
# 5935        0.0          whatsapp-free         0.871795
# 6409        0.0         whatsappstatus         0.857143
# 16750       1.0       whatsapp-18.ikwb         0.833333
# 1716        1.0      whatsapps.mrslove         0.823529
# 2243        1.0           joinwhatsaap         0.819444
# 141         1.0     whatsapp18girl.4pu         0.814815
# 16256       1.0    joinwhatsapp1.hicam         0.807018
# 21093       1.0    whatsapps.instanthq         0.807018
# 15223       1.0    whattsapps.misecure         0.807018
# 9566        1.0    whatsapp.blazagency         0.807018
# 9431        1.0    whatsapp-grup.dynip         0.807018
# 6150        1.0    whatsapjpgs.duckdns         0.807018
# 6763        1.0  whatsapp-grubsx1.zzux         0.793651
